# %% [markdown]
# # Solutaion Day 2

# %% [markdown]
# 1. Using the Taxi environment in Open AI , reset the environment.
# 2. Using random moves pickup a passenger and drop the passenger at his desired location. Find out how many moves had to
# 3. Implement the Q Learning Algorith on the Taxi environment.
# 4. Render any  3 environments in OpenAi gym.

# %%
import gym
import numpy as np

# %%
env=gym.make("Taxi-v2")

# %%
state=env.reset()
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
action=env.action_space.sample()
state,reward,done,info=env.step(action)

# %%
c1=1
reward=0
while reward!=20:
    action=env.action_space.sample()
    sate,reward,done,info=env.step(action)
    env.render()
    c1+=1
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# ...

# %%
print "Number of steps for final state= ",c1
# Out:
# Number of steps for final state=  2359

# %%
Q=np.zeros([500,6])
c2=1
reward=0
gamma=0.8
while reward!=20:
    action=np.argmax(Q[state])
    state2,reward,done,info=env.step(action)
    Q[state,action]=reward+gamma*np.max(Q[state2])
    state=state2
    env.render()
    c2+=1
# Out:
# +---------+
# |R: | : :G|
# |_: : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# |_: : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# ...

# %%
print "Number of steps for final state= ",c2
# Out:
# Number of steps for final state=  27

# %%
env=gym.make("Pendulum-v0")
state=env.reset()
env.render()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <type 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <type 'numpy.float32'>. Please provide explicit dtype.
# True

# %%
env=gym.make("MountainCarContinuous-v0")
state=env.reset()
env.render()

# %%
env=gym.make("CartPole-v1")
state=env.reset()
env.render()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <type 'numpy.float32'>. Please provide explicit dtype.
# True
